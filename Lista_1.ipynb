# %% [markdown]
# <a href="https://colab.research.google.com/github/mariaelimanascimento-gif/nova-git-3ds/blob/main/Lista_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Exercício 1

# %%
nome = input ("Qual o seu nome ? ")
sobrenome = input ("Qual o seu sobrenome ? ")
print(f"O seu nome é: {nome} {sobrenome}")
# Out:
# Qual o seu nome ? maria
# Qual o seu sobrenome ? lima
# O seu nome é: maria lima

# %% [markdown]
# Exercício 2

# %%
numero1 = int(input ("Digite um número "))
numero2 = int(input ("Digite outro número "))
print(f"O resultado é: {numero1 - numero2}")
# Out:
# Digite um número 10
# Digite outro número 5
# O resultado é: 5

# %% [markdown]
# Exercício 3

# %%
numA = input ("Digite um número ")
numB = input ("Digite outro número ")
print ("O primeiro número é: ", numB)
print ("O segundo número é: ", numA)
# Out:
# Digite um número 10
# Digite outro número 20
# O primeiro número é:  20
# O segundo número é:  10

# %% [markdown]
# Exercício 4

# %%
prova1 = float(input("Digite a nota da primeira prova: "))
prova1 = prova1 * 2

prova2 = float(input("Digite a nota da segunda prova: "))
prova2 = prova2 * 3

prova3 = float(input("Digite a nota da terceira prova: "))
prova3 + prova3 * 5

media= (prova1 + prova2 + prova3) /10
print ("Seu resultado é: ", media)
# Out:
# Digite a nota da primeira prova: 6
# Digite a nota da segunda prova: 4
# Digite a nota da terceira prova: 8
# Seu resultado é:  3.2

# %% [markdown]
# Exercício 5

# %%
altura= float(input("Insira a altura da caixa d'água: "))
largura= float(input("Insira a largura da caixa d'água: "))
profundidade= float(input("Insira a profundidade da caixa d'água: "))

volume= altura * largura * profundidade
print ("O volume da caixa d'água é: ", volume)
# Out:
# Insira a altura da caixa d'água: 6
# Insira a largura da caixa d'água: 8
# Insira a profundidade da caixa d'água: 6
# O volume da caixa d'água é:  288.0

# %% [markdown]
# Exercício 6

# %%
altura= float(input("Insira a altura do triângulo em cm: : "))
base= float(input("Insira a base do triângulo em cm: : "))
area= altura * base /2

print ("A área do triângulo é: ", area)
# Out:
# Insira a altura do triângulo em cm: : 15
# Insira a base do triângulo em cm: : 5
# A área do triângulo é:  37.5
